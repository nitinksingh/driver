# %%
from __future__ import division
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pylab
import itertools
import math
from matplotlib import rc
import scipy as sc
import pandas as pd

from cna_analysis import get_pancancer_cna_summary
from mutation_analysis import get_pancancer_mutation_summary

# %%
gene = 0; refresh = False
summary = get_pancancer_cna_summary(gene, refresh)
pylab.rcParams['figure.figsize'] = (18.0, 12.0)
summary.plot(kind='box', logy=True, rot=30); 
plt.ylabel('Number of Extreme CNA Events in Samples');

# %%
# Do pancancer aggregation 
gene = 0; refresh = False    
ns_summary, s_summary = get_pancancer_mutation_summary(gene, refresh)
cna_summary = get_pancancer_cna_summary(gene, refresh)
common_cancers = cna_summary.columns.intersection(ns_summary.columns)
cna_ns_summary = cna_summary.join(ns_summary, how='inner', lsuffix='_CNA', rsuffix='_MUT')
cna_ns_summary.dropna(axis=1, how='all', inplace=True)

# %%
# Show common patients and summary stats for mutation and cna
cna_ns_summary.describe().transpose()
# Out:
#               count         mean          std  min     25%    50%      75%  \
# ACC_CNA          88   314.715909   511.283644    0   12.75   94.5   489.25
# BLCA_CNA        127   698.244094   724.908563    0  105.00  503.0  1042.00
# BRCA_CNA        960   648.186458   758.579459    0   44.75  434.0  1044.25
# CESC_CNA        191   397.413613   566.251991    0   28.50  204.0   580.50
# COAD_CNA        152   210.940789   305.911173    0   11.00   72.0   301.75
# COADREAD_CNA    220   208.495455   294.411238    0   11.00   84.0   301.75
# GBM_CNA         273   139.095238   231.269749    1   30.00   58.0   125.00
# HNSC_CNA        302   463.543046   507.221881    0   92.25  325.0   675.75
# KICH_CNA         66    61.151515   165.027480    0    1.00    3.0    12.75
# KIRC_CNA        415   245.134940   375.704493    0    2.00    8.0   545.00
# KIRP_CNA        161    88.496894   203.982479    0    1.00    3.0    37.00
# LGG_CNA         286   306.108392   481.565006    0    3.00   52.5   434.75
# LIHC_CNA        193   540.357513   622.161548    0   36.00  373.0   855.00
# LUAD_CNA        172   596.308140   595.878342    0  152.25  414.0   866.25
# LUSC_CNA        177   759.225989   665.973087    0  267.00  566.0  1047.00
# OV_CNA          227  1242.427313  1052.223158    0  463.50  988.0  1747.50
# PAAD_CNA         90   300.855556   390.391177    0   15.25  132.5   491.75
# PRAD_CNA        258   426.461240   586.489603    0   11.25  141.5   725.75
# READ_CNA         68   194.897059   261.964287    0   12.50   85.5   269.50
# STAD_CNA        218   463.692661   605.047092    0   44.75  285.5   667.00
# THCA_CNA        399    41.804511   168.471616    0    1.00    2.0     6.00
# UCEC_CNA        242   375.074380   748.868520    0    2.00    9.5   332.25
# UCS_CNA          56   867.089286   735.149169    0  385.25  709.5  1256.00
# ACC_MUT          88   131.977273   228.985417   31   59.75   73.5   107.25
# BLCA_MUT        127   222.299213   190.252644   10  101.00  168.0   278.50
# BRCA_MUT        960    63.036458   214.033784    1   19.00   30.0    54.00
# CESC_MUT        191   152.015707   264.427634    1   48.00   77.0   139.50
# COAD_MUT        152   302.592105   755.111573   20   53.00   82.0   126.25
# COADREAD_MUT    220   285.354545   920.726625   19   49.00   73.5   104.25
# GBM_MUT         273    53.296703    19.177668    2   42.00   51.0    64.00
# HNSC_MUT        302   138.860927   136.751517    3   65.00  104.0   154.75
# KICH_MUT         66    70.333333    90.495445   33   45.25   53.5    67.00
# KIRC_MUT        415    42.607229    21.767934    1   30.50   42.0    54.50
# KIRP_MUT        161    67.043478    28.224180   11   47.00   67.0    81.00
# LGG_MUT         286    32.923077    28.396461    1   21.00   30.0    40.00
# LIHC_MUT        193    99.761658   103.211732    1   53.00   81.0   119.00
# LUAD_MUT        172   640.465116  1100.405626   22  199.25  423.0   780.50
# LUSC_MUT        177   272.276836   235.947816    1  163.00  225.0   302.00
# OV_MUT          227    36.797357    29.932422    1   14.00   30.0    50.00
# PAAD_MUT         90   285.011111  1636.280514   41   80.25  102.0   132.75
# PRAD_MUT        258    39.542636    61.678848    2   24.00   32.0    40.00
# READ_MUT         68   185.470588   726.783868   19   43.00   59.5    80.25
# STAD_MUT        218   360.064220   700.156115    9   68.25  118.0   321.25
# THCA_MUT        399    12.691729     8.280431    1    7.00   11.0    16.00
# UCEC_MUT        242   540.603306  1614.539419    1   38.00   53.5   259.75
# UCS_MUT          56   135.410714   498.530268   29   44.00   53.5    63.25
#
#                 max
# ACC_CNA        3306
# BLCA_CNA       3096
# BRCA_CNA       5440
# CESC_CNA       4235
# COAD_CNA       1773
# COADREAD_CNA   1773
# GBM_CNA        1432
# HNSC_CNA       2895
# KICH_CNA        845
# KIRC_CNA       1859
# KIRP_CNA       1401
# LGG_CNA        3754
# LIHC_CNA       3279
# LUAD_CNA       2615
# LUSC_CNA       3584
# OV_CNA         6344
# PAAD_CNA       1817
# PRAD_CNA       4351
# READ_CNA       1232
# STAD_CNA       4063
# THCA_CNA       1638
# UCEC_CNA       3506
# UCS_CNA        3531
# ACC_MUT        1835
# BLCA_MUT       1239
# BRCA_MUT       4417
# CESC_MUT       1882
# COAD_MUT       6954
# COADREAD_MUT   9946
# GBM_MUT         174
# HNSC_MUT       1430
# KICH_MUT        771
# KIRC_MUT        124
# KIRP_MUT        228
# LGG_MUT         430
# LIHC_MUT       1204
# LUAD_MUT      13391
# LUSC_MUT       2504
# OV_MUT          157
# PAAD_MUT      15629
# PRAD_MUT        829
# READ_MUT       5753
# STAD_MUT       6218
# THCA_MUT         64
# UCEC_MUT      10141
# UCS_MUT        3743
